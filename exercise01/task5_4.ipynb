# %%
from automaton import Scenario
from automaton import Automaton
from automaton import Parameters
import visualization
import numpy as np
from enum import Enum
from IPython.display import HTML
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import animation
import math
import random
import scenario_reader

# %% [markdown]
# ### Additional tests

# %%
test_same_order_scenario = scenario_reader.make_scenario('scenarios/measurement_fundamental_density_40_scenario.json')
test_same_order_automaton = Automaton(test_same_order_scenario)
test_same_order_data = test_same_order_automaton.simulate_pedestrians()
test_same_order_plot = visualization.plot_automaton_states(test_same_order_data[85])
test_same_order_plot.savefig("results/task5_update_pedestrians_same_order.pdf")
# Out:
# Simulation stopped after 318 simulation steps, since all pedestrians are already at their target.
# Finished simulating 318 simulation steps.

# %%
test_shuffled_scenario = scenario_reader.make_scenario('scenarios/measurement_fundamental_density_40_scenario.json')
test_shuffled_automaton = Automaton(test_shuffled_scenario, update_pedestrians_shuffled=True)
test_shuffled_data = test_shuffled_automaton.simulate_pedestrians()
test_shuffled_plot = visualization.plot_automaton_states(test_shuffled_data[85])
test_shuffled_plot.savefig("results/task5_update_pedestrians_shuffled.pdf")
# Out:
# Simulation stopped after 497 simulation steps, since all pedestrians are already at their target.
# Finished simulating 497 simulation steps.
